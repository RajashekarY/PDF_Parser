# %%
#Import required Packages
from nltk.corpus import stopwords
from wordcloud import STOPWORDS
#example_sent = EXAMPLE_TEXT
stop_words = set(stopwords.words('english'))
print("Genric stopWords:",len(stop_words))
stop_words.update(STOPWORDS)
print("These are the stopWords from both Modules:",len(stop_words))
customStops = {'©', '&',"'m", '™',",",'(',')','--','.','e','Bla', 'bla', '=', '±', 'mc',"...","!","@","#","$","%","^","&","*","[","]" '²','/',':','II','?','III',"''",'``',"'ve","Dr."}
stop_words.update(customStops)
ext_stop_words = set()
for i in stop_words:
    ext_stop_words.update((i).title())
    ext_stop_words.update((i).upper())
    ext_stop_words.update((i).lower())
    ext_stop_words.update((i).capitalize())
stop_words.update(ext_stop_words)
print("Final Stop Words:",len(stop_words))
# Out:
# Genric stopWords: 179
# These are the stopWords from both Modules: 225
# Final Stop Words: 299

# %%
import pdftotext
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Load your PDF
with open('/home/scientist/Documents/DataScience/myData/eftos-ent-kingdom-of-a-thousand (1).pdf', "rb") as file:
    pdf = pdftotext.PDF(file)
print("No.of pages in this PDF:",len(pdf))
# Out:
# No.of pages in this PDF: 134

# %%
def plot_wordcloud(wordcloud):
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
paper = 1
for page in pdf:
    print("         Page:",paper)
    if len(page)>0:
        #print(page)
        #print(80*'_')
        token_page = word_tokenize(page)
        filtered_sentence = [w for w in token_page if not w in stop_words]
        print(filtered_sentence)
        #wordcloud = WordCloud().generate(page)
        #plot_wordcloud(wordcloud)
    else:print("no Words for Making WordCloud")
    paper = paper+1
    #print(word_tokenize(page))
    #print(type(page))
# Out:
#          Page: 1
# no Words for Making WordCloud
#          Page: 2
# no Words for Making WordCloud
#          Page: 3
# ['Eftos', 'Ent', 'Kingdom', 'thousand', 'Better', 'read', 'something', 'First', 'without', 'central', 'word', 'ABSOLUTE', 'Eftos', 'Ent']
#          Page: 4
# ...

# %%
s = ["X","XII","V","III","gellop"]

# %%
for i in s:
    print(i,i.isupper())
    if i.isupper()==True:
        s.remove(i)
        #print(s)
print(s)
# Out:
# X True
# V True
# gellop False
# ['XII', 'III', 'gellop']

# %%
print(s)
# Out:
# ['XII', 'III', 'gellop']

# %% [markdown]
# ```python
# import pdftotext
#
# # Load your PDF
# with open("lorem_ipsum.pdf", "rb") as f:
# pdf = pdftotext.PDF(f)
#
# # If it's password-protected
# with open("secure.pdf", "rb") as f:
# pdf = pdftotext.PDF(f, "secret")
#
# # How many pages?
# print(len(pdf))
#
# # Iterate over all the pages
# for page in pdf:
# print(page)
#
# # Read some individual pages
# print(pdf[0])
# print(pdf[1])
#
# # Read all the text into one string
# print("\n\n".join(pdf))
# ```
# ### https://pypi.org/project/pdftotext/

# %%
import fitz
import pathlib
pathlib.Path('./PDFimages').mkdir(parents=True, exist_ok=True)
doc = fitz.open("/home/scientist/Documents/DataScience/myData/eftos-ent-kingdom-of-a-thousand (1).pdf")
for i in range(len(doc)):
    for img in doc.getPageImageList(i):
        #print(type(doc.getPageImageList(i)))
        xref = img[0]
        pix = fitz.Pixmap(doc, xref)
        if pix.n < 5:       # this is GRAY or RGB
            pix.writePNG("./PDFimages/p%s-%s.png" % (i, xref))
        else:               # CMYK: convert to RGB first
            pix1 = fitz.Pixmap(fitz.csRGB, pix)
            pix1.writePNG("./PDFimages/p%s-%s.png" % (i, xref))
            pix1 = None
        pix = None

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."

print(sent_tokenize(EXAMPLE_TEXT))
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and Python is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
example_sent = "This is a sample sentence, showing off the stop words filtration."

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)

filtered_sentence = [w for w in word_tokens if not w in stop_words]

filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(word_tokens)
print(set(filtered_sentence))
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# {'This', 'showing', 'words', 'filtration', '.', 'sample', ',', 'stop', 'sentence'}

# %%
# Part of speech
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
#print(train_text)
print(sample_text)
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()
# Out:
# PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION
#
# January 31, 2006
#
# THE PRESIDENT: Thank you all. Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream. Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King. (Applause.)
#
# ...
